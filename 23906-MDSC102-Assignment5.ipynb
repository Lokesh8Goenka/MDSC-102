# %% [markdown]
# ## BoxPlot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
name = ["Class","Alcohol","Malic acid","Ash","Alcalinity of ash","Magnesium","Total phenols","Flavanoids","Nonflavanoid phenols","Proanthocyanins","Color intensity","Hue","OD280/OD315 of diluted wines","Proline"]
df = pd.read_csv('./wine/wine.data' ,names = name)
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
sns.boxplot(data = df, x = "Malic acid")
# Out:
# <Axes: xlabel='Malic acid'>

# %%
sns.histplot(data = df, x = "Magnesium")
# Out:
# <Axes: xlabel='Magnesium', ylabel='Count'>

# %%
plt.figure(figsize=(20,20))
j = 1
for i in name[1:]:
        plt.subplot(4,4,j)
        sns.boxplot(df, x='Class', y=i, hue='Class')
        j += 1

plt.show()

# %% [markdown]
# 1. Alcohol and Class
#     * class 1 - The alcohol levels is normally skewed
#     * class 2 - The alcohol levels are left skewed and outliers are also present
#     * class 3 - The alcohol levels are Right skewed
#
# 2. Malic Acid and Class
#     * class 1 - The malic acid levels are Right skewed with outliers
#     * class 2 - The malic acid levels are Right skewed with outliers
#     * class 3 - Right skewed
#
# 3. Ash and Class
#     * class 1 - Normally skewed with outliers
#     * class 2 - Right Skewed with outliers
#     * class 3 - Right Skewed
#
# 4. Alcanity of Ash and alcohol
#     * class 1 - Right skewed with outliers
#     * class 2 - Normally skewed with outliers
#     * class 3 - Right skewed
#
# 5. Magnesium and Class
#     * class 1 - Right skewed
#     * class 2 - Right skewed with outliers
#     * class 3 - Right skewed
#
# 6. Total Phenols and Class
#     * class 1 - Normally skewe with outliers
#     * class 2 - Right skewed
#     * class 3 - Left skewed with outliers
#
# 7. Flavaniods and Class
#     * class 1 - Right skewed
#     * class 2 - Normally skewed with outliers
#     * class 3 - Right skewed with outliers
#
# 8. Nonflavaniods and Class
#     * class 1 - Left skewed with outliers
#     * class 2 - Right skewed with outliers
#     * class 3 - Left skewed with outliers
#
# 9. Proanthocyanins and class
#     * class 1 - Left skewed with outliers
#     * class 2 - Normally skewed with outliers
#     * class 3 - Right skewed with outliers
#
# 10. Color intensity and class
#     * class 1 - Right skewed with outliers
#     * class 2 - Right skewed with outliers
#     * class 3 - Right Skewed
#
# 11. Hue and Class
#     * class 1 - Left Skewed
#     * class 2 - Right Skewed with outliers
#     * class 3 - Right skewed
#
# 12. Dilution and Class
#     * class 1 - Right Skewed
#     * class 2 - Left Skewed
#     * class 3 - Normally distributed with outliers
#
# 13. Proline and Class
#     * class 1 - Right Skewed
#     * class 2 - Right skewed with outliers
#     * class 3 - Right skewed

# %%
plt.figure(figsize=(40,80))
j = 1
k = 1
x = range(1,4)
for k in x:
        for i in name[1:]:

                plt.subplot(13,3,j)
                plt.title("{} of class {}" .format(i,k))
                sns.histplot(df[df["Class"] == k][i], kde = True)
                j += 1

plt.show()
