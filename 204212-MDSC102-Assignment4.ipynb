# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
name = ["Class","Alcohol","Malic acid","Ash","Alcalinity of ash","Magnesium","Total phenols","Flavanoids","Nonflavanoid phenols","Proanthocyanins","Color intensity","Hue","OD280/OD315 of diluted wines","Proline"]
df = pd.read_csv('./wine/wine.data' ,names = name)
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
sns.countplot(x = "Alcohol" , data = df)
# Out:
# <Axes: xlabel='Alcohol', ylabel='count'>

# %%
sns.scatterplot(x = "Alcohol", y = "Malic acid", hue= 'Class', data = df)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic acid'>

# %%
plt.figure(figsize=(20,20))
for index, column in enumerate(df):
    if index > 1 : 
        plt.subplot(4,3,index - 1)
        sns.scatterplot(df, x='Alcohol', y=column, hue='Class')

plt.show()

# %% [markdown]
# ## Infernce from the plots

# %% [markdown]
# 1. Malic Acid and Alcohol
#     * class 1 - low level of malic acid and high level of alcohol
#     * class 2 - low level of malic acid and low level of alcohol
#     * class 3 - no inference can be made
#
# 2. Ash and Alcohol
#     * class 1 - high level of ash and high level of alcohol
#     * class 2 - high level of ash and low level of alcohol
#     * class 3 - high level of ash and high level of alcohol
#
# 3. Alcalinity of Ash and Alcohol
#     * class 1 - low level of alcaline ash and high level of alcohol
#     * class 2 - high level of alcaline ash and low level of alcohol
#     * class 3 - high level of alcaline ash and high level of alcohol
#
# 4. Magnesium and Alcohol
#     * class 1 - high level of magnesium and high level of alcohol
#     * class 2 - low level of magnesiuma and low level of alcohol
#     * class 3 - high level of magnesium and high level of alcohol
#
# 5. Total Phenols and Alcohol
#     * class 1 - high levels of phenols and high level of alcohol
#     * class 2 - no inference can be made
#     * class 3 - low level of phenols and low level of alcohol
#
# 6. Flavanoids and Alcohol
#     class 1 - high level of flavanoids and high level of alcohol
#     class 2 - for any level of flavanoids and low level of alcohol
#     class 3 - low level of flavanoids and high level of alcohol
#
# 7. NonFlavanoid phenols and Alcohol
#     * class 1 - low level of NonFlavanoid phenols and high level of alcohol
#     * class 2 - for any levels of NonFlavanoid phenols , low level of alcohol
#     * class 3 - No inference can be made
#
# 8. Proanthocyanins and Alcohol
#     * class 1 - low level of Proanthocyanins and high levels of alcohol
#     * class 2 - For any levels of Proanthocyanins, low levels of alcohol
#     * class 3 - low level of Proanthocyanins and high levels of alcohol
#
# 9. Color Intensity and Alcohol
#     * class 1 - low level of color intensity and high level of alcohol
#     * class 2 - low level of color intensity and low level of alcohol
#     * class 3 - No inference can be made
#
# 10. Hue and color
#     * class 1 - high level of hue and high level of alcohol
#     * class 2 - for any level of hue alcohol level is low
#     * class 3 - low level of hue and high level of alcohol
#
# 11. OD280/OD315 of diluted wines
#     * class 1 - high level of dilution and high levels of alcohol
#     * class 2 - high level of dilution and low levels of alcohol
#     * class 3 - low level of dilution and high levels of alcohol
#
# 12. Proline And Alcohol
#     * class 1 - high level of proline and high levels of alcohol
#     * class 2 - low level of proline and low levels of alcohol
#     * class 3 - low level of proline and high levels of alcohol
